# %%
# Take the V1 example and use for inference in the app. Testing notebook

# %%
# Import the required modules
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# Pre-Processing
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# Models
from sklearn.neighbors import NearestNeighbors

# suppress warnings
import warnings
warnings.filterwarnings('ignore')

import pickle

# %%
PICKLE_PATH = "../app/board_games_pipeline.pkl"
COLS_TO_DROP = []
META_COLS = ['game_id', 'name']
FEATURE_COLS = ['max_players', 'max_playtime', 'min_age', 'min_players',
   'min_playtime', 'playing_time', 'category', 'mechanic',
   'average_rating', 'users_rated', 'category_count', 'mechanic_count',
   'has_expansion', 'binned_playtime', 'binned_mechanics',
   'binned_min_age', 'binned_category', 'len_description',
   'description_sentiment',]
NUMERIC_FEATURES = ['max_players', 'max_playtime', 'min_age', 'min_players',
   'min_playtime', 'playing_time', 
   'average_rating', 'users_rated', 'category_count', 'mechanic_count',
   'len_description', 'description_sentiment',]
BINARY_FEATURES = ['has_expansion']
CATEGORICAL_FEATURES = ['category', 'mechanic', 'binned_playtime', 'binned_mechanics',
   'binned_min_age', 'binned_category',]

# %% [markdown]
# ## Define Preprocessor & Model

# %%
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),  # Fill missing values with the mean
    ('scaler', StandardScaler())])

# %%
binary_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent', missing_values=pd.NA)),  # Fill missing values
    ('label', OrdinalEncoder())])  # Convert binary features to ordinal values

# %%
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent', missing_values=pd.NA)),  # Fill missing values
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])  # Apply one-hot encoding

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, NUMERIC_FEATURES),  # Numeric features preprocessing
        ('binary', binary_transformer, BINARY_FEATURES),  # Binary features preprocessing (if any)
        ('cat', categorical_transformer, CATEGORICAL_FEATURES)])

# %%
nn_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', NearestNeighbors(metric="cosine"))    # N Neighhors default = 5 
])

# %% [markdown]
# ## Read & Process the Data

# %%
df = pd.read_csv("resources/ml_clean.csv")
df = df.dropna(how="any").reset_index(drop=True)
df = df.drop(columns=COLS_TO_DROP)
df["name_lower"] = df['name'].str.lower()
df = df.drop_duplicates(subset=['name_lower']).reset_index(drop=True)
df
# Out:
#       game_id  max_players  max_playtime  min_age  min_players  min_playtime  \
# 0           1            5           240       14            3           240
# 1           2            4            30       12            3            30
# 2           3            4            60       10            2            30
# 3           4            4            60       12            2            60
# 4           5            6            90       12            3            90
# ...       ...          ...           ...      ...          ...           ...
# 9354   214996            2           480       12            1            30
# 9355   215437            5            45       13            2            45
# 9356   215471            4            20       12            2            20
# 9357   216201            6           120       12            2            20
# 9358   216725            5            60       14            1            30
#
#                                                    name  playing_time  \
# 0                                            Die Macher           240
# 1                                          Dragonmaster            30
# 2                                               Samurai            60
# 3                                        Tal der Könige            60
# 4                                               Acquire            90
# ...                                                 ...           ...
# 9354  Silver Bayonet: The First Team in Vietnam, 196...           480
# 9355               Codex: Card-Time Strategy – Core Set            45
# 9356                                     Wind the Film!            20
# 9357                                  Robo Rally (2016)           120
# 9358    Villages of Valeria: Deluxe Kickstarter Edition            60
#
#                category                       mechanic  average_rating  \
# 0              economic  area control / area influence         7.66508
# 1             card game                   trick-taking         6.60815
# 2     abstract strategy  area control / area influence         7.44119
# 3               ancient  action point allowance system         6.60675
# 4              economic                hand management         7.35830
# ...                 ...                            ...             ...
# 9354        vietnam war                hex-and-counter         8.35333
# 9355          card game           deck / pool building         8.08780
# 9356          card game                hand management         7.28016
# 9357         miniatures  action / movement programming         7.45871
# 9358          card game                  card drafting         7.52941
#
#       users_rated  category_count  mechanic_count  has_expansion  \
# 0            4498               3               5              0
# 1             478               2               1              0
# 2           12019               2               4              0
# 3             314               1               4              0
# 4           15195               1               3              0
# ...           ...             ...             ...            ...
# 9354           75               2               1              0
# 9355           82               4               3              1
# 9356           63               1               2              0
# 9357          341               3               4              0
# 9358          119               2               2              0
#
#                   binned_playtime             binned_mechanics  \
# 0     Very Long (121-240 minutes)          Strategic Mechanics
# 1            Short (0-30 minutes)        Card & Pool Mechanics
# 2          Medium (31-60 minutes)          Strategic Mechanics
# 3          Medium (31-60 minutes)          Strategic Mechanics
# 4           Long (61-120 minutes)   Pattern & Design Mechanics
# ...                           ...                          ...
# 9354      Extended (241+ minutes)             Unique Mechanics
# 9355       Medium (31-60 minutes)     Game Structure Mechanics
# 9356         Short (0-30 minutes)        Card & Pool Mechanics
# 9357        Long (61-120 minutes)  Action & Movement Mechanics
# 9358       Medium (31-60 minutes)        Card & Pool Mechanics
#
#         binned_min_age        binned_category  len_description  \
# 0           Teen (13+)               Strategy              222
# 1     Pre-Teen (10-12)  Unknown/Miscellaneous              154
# 2     Pre-Teen (10-12)               Strategy              183
# 3     Pre-Teen (10-12)            History/War              104
# 4     Pre-Teen (10-12)               Strategy              191
# ...                ...                    ...              ...
# 9354  Pre-Teen (10-12)            History/War              186
# 9355        Teen (13+)  Unknown/Miscellaneous               99
# 9356  Pre-Teen (10-12)  Unknown/Miscellaneous              152
# 9357  Pre-Teen (10-12)   Real-life/Simulation              463
# 9358        Teen (13+)  Unknown/Miscellaneous               64
#
#       description_sentiment                                         name_lower
# 0                  0.091012                                         die macher
# 1                  0.055291                                       dragonmaster
# 2                 -0.056250                                            samurai
# 3                 -0.007908                                     tal der könige
# 4                  0.168056                                            acquire
# ...                     ...                                                ...
# 9354               0.127083  silver bayonet: the first team in vietnam, 196...
# 9355              -0.193750               codex: card-time strategy – core set
# 9356               0.318452                                     wind the film!
# 9357               0.008621                                  robo rally (2016)
# 9358               0.233333    villages of valeria: deluxe kickstarter edition
#
# [9359 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['game_id', 'max_players', 'max_playtime', 'min_age', 'min_players',
#        'min_playtime', 'name', 'playing_time', 'category', 'mechanic',
#        'average_rating', 'users_rated', 'category_count', 'mechanic_count',
#        'has_expansion', 'binned_playtime', 'binned_mechanics',
#        'binned_min_age', 'binned_category', 'len_description',
#        'description_sentiment', 'name_lower'],
#       dtype='object')

# %%
X = df[FEATURE_COLS]

# %% [markdown]
# ## Fit & Save Model

# %%
nn_pipeline.fit(X)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['max_players',
#                                                    'max_playtime', 'min_age',
#                                                    'min_players',
#                                                    'min_playtime',
#                                                    'playing_time',
#                                                    'average_rating',
#                                                    'users_rated',
#                                                    'category_count',
#                                                    'mechanic_count',
#                                                    'len_description',
#                                                    'description_sentiment']),
#                                                  ('binary',
#                                                   Pi...
#                                                                                  strategy='most_frequent')),
#                                                                   ('label',
#                                                                    OrdinalEncoder())]),
#                                                   ['has_expansion']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(missing_values=<NA>,
#                                                                                  strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['category', 'mechanic',
#                                                    'binned_playtime',
#                                                    'binned_mechanics',
#                                                    'binned_min_age',
#                                                    'binned_category'])])),
#                 ('classifier', NearestNeighbors(metric='cosine'))])

# %%
payload = {
    "feature_df": df[FEATURE_COLS + ['name']],
    "pipeline": nn_pipeline,
}

# %%
pickle.dump(payload, open(PICKLE_PATH, 'wb'))
