# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from textblob import TextBlob

# %%
# Load the CSV file
file_path = 'resources/clean.csv'  
df = pd.read_csv(file_path)

# %%
# Standardize categorical variables (e.g., lowercase the 'category' column)
df['mechanic'] = df['mechanic'].apply(lambda x: str(x).split(',')[0])
df['category'] = df['category'].apply(lambda x: str(x).split(',')[0])

# %%
# Create a new column for the length of the description
df['len_description'] = df['description'].apply(lambda x: len(x.split(' ')))

# %%
# Create a new column for the sentiment of the description
df['description_sentiment'] = df['description'].apply(lambda x: TextBlob(x).sentiment.polarity)
df.drop(['description'], axis=1, inplace=True)
df.head()
# Out:
#    game_id  max_players  max_playtime  min_age  min_players  min_playtime  \
# 0        1            5           240       14            3           240
# 1        2            4            30       12            3            30
# 2        3            4            60       10            2            30
# 3        4            4            60       12            2            60
# 4        5            6            90       12            3            90
#
#              name  playing_time           category  \
# 0      Die Macher           240           economic
# 1    Dragonmaster            30          card game
# 2         Samurai            60  abstract strategy
# 3  Tal der Könige            60            ancient
# 4         Acquire            90           economic
#
#                         mechanic  average_rating  users_rated  category_count  \
# 0  area control / area influence         7.66508         4498               3
# ...

# %%
# Save the cleaned DataFrame to a CSV file in the resources folder
df.to_csv('resources/ml_clean.csv', index=False)
