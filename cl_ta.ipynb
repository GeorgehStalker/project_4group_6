# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
INPUT_PATH = 'resources/board_games.csv'
CATEGORY_SEP = ','
GENRES = {
    'cat_kids': {"children's game",},
    'cat_war': {'modern warfare', 'wargame', 'american civil war', 'civil war', 'korean war',
            'world war ii', 'american revolutionary war', 'vietnam war', 'american indian wars',
            'world war i', },
}

# %%
# Load the CSV file 
df = pd.read_csv(INPUT_PATH).dropna()

# Display the first few rows and the summary of the DataFrame
print(df.columns)
print(df.shape)
df.head()
# Out:
# Index(['game_id', 'description', 'image', 'max_players', 'max_playtime',
#        'min_age', 'min_players', 'min_playtime', 'name', 'playing_time',
#        'thumbnail', 'year_published', 'artist', 'category', 'compilation',
#        'designer', 'expansion', 'family', 'mechanic', 'publisher',
#        'average_rating', 'users_rated'],
#       dtype='object')
# (163, 22)
#      game_id                                        description  \
# 12        13  In Catan (formerly The Settlers of Catan), pla...
# 44        49  Designer Uwe Rosenberg has a talent for dreami...
# 79        93  In this award-winning game, players take on th...
# 151      181  Possibly the most popular, mass market war gam...
# 226      278  Catan Card Game bears only a slight resemblanc...
#
#                                             image  max_players  max_playtime  \
# 12   //cf.geekdo-images.com/images/pic2419375.jpg            4           120
# 44   //cf.geekdo-images.com/images/pic2824027.jpg            5            30
# 79    //cf.geekdo-images.com/images/pic180538.jpg            5           120
# 151  //cf.geekdo-images.com/images/pic2920766.jpg            6           120
# 226   //cf.geekdo-images.com/images/pic135066.jpg            2            90
#
#      min_age  min_players  min_playtime             name  playing_time  ...  \
# 12        10            3            60            Catan           120  ...
# 44        10            2            30       Mamma Mia!            30  ...
# 79        12            2            60        El Grande           120  ...
# 151       10            2           120             Risk           120  ...
# 226       10            2            90  Catan Card Game            90  ...
#
#                                                 artist  \
# 12   Volkan Baga,Tanja Donner,Pete Fenlon,Jason Haw...
# 44                                     Franz Vohwinkel
# 79                                      Doris Matthäus
# 151                                       (Uncredited)
# 226  Tanja Donner,Pete Fenlon,Jason Hawkins,Matt Sc...
#
#                                        category  \
# 12                                  Negotiation
# 44                                    Card Game
# 79                                  Renaissance
# 151      Negotiation,Territory Building,Wargame
# 226  Card Game,City Building,Territory Building
#
#                                            compilation  \
# 12   CATAN 3D Collector's Edition,Catan: Big Box,Ca...
# 44                  Mamma Mia! con Ingredientes dobles
# 79       El Grande Big Box,El Grande Decennial Edition
# 151  Risk & Castle Risk,Spaß am Erfolg: Karriere, D...
# 226  Die Siedler von Catan: Das Kartenspiel – 10th ...
#
#                               designer  \
# 12                        Klaus Teuber
# 44                       Uwe Rosenberg
# 79      Wolfgang Kramer,Richard Ulrich
# 151  Albert Lamorisse,Michael I. Levin
# 226                       Klaus Teuber
#
#                                              expansion  \
# 12   20 Jahre Darmstadt Spielt,Brettspiel Adventska...
# 44   Mamma Mia: Double Ingredients,Mamma Mia: Joker...
# 79   The El Grande Expansions,El Grande: Grandissim...
# 151  Concurrent,La Conquête du Monde revised,Euro R...
# 226  Catan Card Game: Artisans & Benefactors,Catan ...
#
#                                                 family  \
# 12                       Catan,Promotional Board Games
# 44                           Food / Cooking,Mamma Mia!
# 79                            Country: Spain,El Grande
# 151  Components: Miniatures,Hasbro Nostalgia Series...
# 226  Catan,Die Siedler von Catan: Das Kartenspiel /...
#
#                                               mechanic  \
# 12   Dice Rolling,Hand Management,Modular Board,Rou...
# 44                              Hand Management,Memory
# 79   Area Control / Area Influence,Area Movement,Au...
# 151  Area Control / Area Influence,Area Movement,Di...
# 226  Card Drafting,Dice Rolling,Hand Management,Tra...
#
#                                              publisher average_rating  \
# 12   KOSMOS,999 Games,Albi,Astrel Games,Bergsala En...        7.26569
# 44   ABACUSSPIELE,Brain Games,cutia.ro,dV Giochi,G3...        6.48827
# 79   Hans im Glück Verlags-GmbH,999 Games,Användbar...        7.80446
# 151  (Unknown),Alga,Barnes & Noble,Borras Plana S.A...        5.57906
# 226  999 Games,Competo / Marektoy,Devir,Filosofia É...        6.77393
#
#     users_rated
# 12        67655
# 44         4824
# 79        18423
# 151       21836
# 226       11105
#
# [5 rows x 22 columns]

# %%
# Check for missing values
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Series([], dtype: int64)

# %%
# Remove duplicates
df = df.drop_duplicates()

# Check the number of rows before and after
print("Number of rows after removing duplicates:", len(df))
# Out:
# Number of rows after removing duplicates: 163

# %%
# Example: Standardize categorical variables (e.g., lowercase the 'category' column)
df['category'] = df['category'].str.lower()

# Display unique categories to confirm changes
print(df['category'].unique())
df['category'].iloc[0]
# Out:
# ['negotiation' 'card game' 'renaissance'
#  'negotiation,territory building,wargame'
#  'card game,city building,territory building'
#  'bluffing,card game,city building,fantasy,medieval' 'ancient,wargame'
#  'city building,medieval,territory building'
#  'deduction,medieval,murder/mystery,religious' 'card game,mafia'
#  'wargame,world war ii'
#  'card game,collectible components,fantasy,fighting,medieval'
#  'card game,fantasy,fighting,humor'
#  'card game,collectible components,fighting,horror,political'
#  'science fiction' 'abstract strategy,animals'
#  'economic,political,wargame,world war ii'
#  'city building,economic,farming' 'animals,bluffing,farming,puzzle'
#  'animals,card game,humor,negotiation'
#  'american west,bluffing,card game,deduction,fighting'
#  'fighting,science fiction,wargame' 'fantasy,miniatures,wargame'
#  'napoleonic,wargame' 'arabian,city building,medieval'
#  'science fiction,wargame' 'vietnam war,wargame'
#  'card game,fighting,humor'
#  'action / dexterity,card game,party game,real-time' 'trains,travel'
#  'bluffing,card game,exploration,party game' 'card game,fantasy,fighting'
#  'adventure,dice,fantasy,novel-based,territory building,wargame'
#  'card game,fighting,horror,humor' 'fantasy,miniatures,science fiction'
#  'miniatures,science fiction' 'horror,miniatures,zombies'
#  'card game,fantasy,humor,party game'
#  'game system,medieval,political,science fiction'
#  'economic,medieval,territory building' 'abstract strategy'
#  'renaissance,transportation' 'economic,renaissance'
#  'bluffing,deduction,horror,murder/mystery,party game'
#  'card game,farming,negotiation' 'aviation / flight,wargame,world war ii'
#  'economic,farming' 'animals,bluffing,racing'
#  'american west,bluffing,card game,deduction,fighting,humor'
#  'economic,medieval'
#  'ancient,bluffing,card game,civil war,fighting,novel-based'
#  'card game,humor,pirates' 'card game,medieval'
#  'fighting,miniatures,science fiction'
#  'bluffing,card game,deduction,horror,murder/mystery,negotiation,party game'
#  'american west,city building,economic'
#  'fantasy,fighting,territory building' 'bluffing,card game,fighting'
#  'fighting,science fiction' 'economic,fantasy,fighting,humor'
#  'city building' 'dice,science fiction' 'bluffing,card game,medieval'
#  'economic,novel-based,trains' 'dice,horror,humor,party game,zombies'
#  "card game,children's game,educational,party game,real-time,sports"
#  'card game,civilization' 'abstract strategy,dice,number'
#  'card game,territory building' 'card game,fantasy' 'mythology'
#  'miniatures,nautical,post-napoleonic,science fiction,wargame,world war i'
#  'city building,medieval' 'medieval'
#  'ancient,book,medieval,miniatures,wargame' 'card game,economic,humor'
#  'card game,deduction,memory' 'economic,nautical'
#  'medieval,territory building'
#  'adventure,dice,electronic,exploration,real-time'
#  'civilization,economic,fantasy,territory building'
#  'card game,territory building,trains' 'travel' 'adventure,fantasy,horror'
#  'card game,deduction,renaissance'
#  'bluffing,card game,deduction,party game,political'
#  'card game,dice,exploration,fantasy' 'bluffing,card game,print & play'
#  'bluffing,card game,deduction,novel-based,renaissance'
#  'bluffing,card game,deduction' 'bluffing,card game,exploration'
#  'card game,city building,dice'
#  'ancient,card game,fantasy,humor,mythology'
#  'city building,negotiation,political'
#  'card game,fighting,science fiction' 'real-time,zombies'
#  'bluffing,horror,zombies'
#  "card game,children's game,humor,nautical,pirates"
#  'card game,science fiction,sports' 'ancient,territory building'
#  'animals,card game,prehistoric' 'adventure,dice,exploration,real-time'
#  'bluffing,card game,deduction,science fiction'
#  'abstract strategy,city building'
#  'adventure,economic,fantasy,fighting,humor'
#  'science fiction,space exploration,territory building'
#  'dice,science fiction,space exploration' 'medieval,religious,travel'
#  'adventure,card game,fantasy' 'card game,city building'
#  'bluffing,deduction,party game,real-time' 'card game,number'
#  'dice,fantasy,fighting' 'action / dexterity'
#  'card game,city building,fantasy' 'nautical'
#  'abstract strategy,animals,dice,game system,science fiction,space exploration']
# 'negotiation'

# %%
# get all orig  cat for to make GENRES dictionary
# orignal_categories = list(set(df.category.str.cat(sep=CATEGORY_SEP).split(CATEGORY_SEP)))
# orignal_categories

# %%
def get_genres(row):
    raw_categories = set(row['category'].split(CATEGORY_SEP))
    # Now use GENRES and raw_genres to produce a dictionary genres
    genres = {}
    for good_genre, original_genre_strings in GENRES.items():       
        genres[good_genre] = not original_genre_strings.isdisjoint(raw_categories)
       
    return genres.values()

# %%
df[list(GENRES.keys())] = df.apply(get_genres, axis='columns', result_type='expand')
print(df.columns)
print(df.shape)
df.head()
# Out:
# Index(['game_id', 'description', 'image', 'max_players', 'max_playtime',
#        'min_age', 'min_players', 'min_playtime', 'name', 'playing_time',
#        'thumbnail', 'year_published', 'artist', 'category', 'compilation',
#        'designer', 'expansion', 'family', 'mechanic', 'publisher',
#        'average_rating', 'users_rated', 'cat_kids', 'cat_war'],
#       dtype='object')
# (163, 24)
#      game_id                                        description  \
# 12        13  In Catan (formerly The Settlers of Catan), pla...
# 44        49  Designer Uwe Rosenberg has a talent for dreami...
# 79        93  In this award-winning game, players take on th...
# 151      181  Possibly the most popular, mass market war gam...
# 226      278  Catan Card Game bears only a slight resemblanc...
#
#                                             image  max_players  max_playtime  \
# 12   //cf.geekdo-images.com/images/pic2419375.jpg            4           120
# 44   //cf.geekdo-images.com/images/pic2824027.jpg            5            30
# 79    //cf.geekdo-images.com/images/pic180538.jpg            5           120
# 151  //cf.geekdo-images.com/images/pic2920766.jpg            6           120
# 226   //cf.geekdo-images.com/images/pic135066.jpg            2            90
#
#      min_age  min_players  min_playtime             name  playing_time  ...  \
# 12        10            3            60            Catan           120  ...
# 44        10            2            30       Mamma Mia!            30  ...
# 79        12            2            60        El Grande           120  ...
# 151       10            2           120             Risk           120  ...
# 226       10            2            90  Catan Card Game            90  ...
#
#                                            compilation  \
# 12   CATAN 3D Collector's Edition,Catan: Big Box,Ca...
# 44                  Mamma Mia! con Ingredientes dobles
# 79       El Grande Big Box,El Grande Decennial Edition
# 151  Risk & Castle Risk,Spaß am Erfolg: Karriere, D...
# 226  Die Siedler von Catan: Das Kartenspiel – 10th ...
#
#                               designer  \
# 12                        Klaus Teuber
# 44                       Uwe Rosenberg
# 79      Wolfgang Kramer,Richard Ulrich
# 151  Albert Lamorisse,Michael I. Levin
# 226                       Klaus Teuber
#
#                                              expansion  \
# 12   20 Jahre Darmstadt Spielt,Brettspiel Adventska...
# 44   Mamma Mia: Double Ingredients,Mamma Mia: Joker...
# 79   The El Grande Expansions,El Grande: Grandissim...
# 151  Concurrent,La Conquête du Monde revised,Euro R...
# 226  Catan Card Game: Artisans & Benefactors,Catan ...
#
#                                                 family  \
# 12                       Catan,Promotional Board Games
# 44                           Food / Cooking,Mamma Mia!
# 79                            Country: Spain,El Grande
# 151  Components: Miniatures,Hasbro Nostalgia Series...
# 226  Catan,Die Siedler von Catan: Das Kartenspiel /...
#
#                                               mechanic  \
# 12   Dice Rolling,Hand Management,Modular Board,Rou...
# 44                              Hand Management,Memory
# 79   Area Control / Area Influence,Area Movement,Au...
# 151  Area Control / Area Influence,Area Movement,Di...
# 226  Card Drafting,Dice Rolling,Hand Management,Tra...
#
#                                              publisher average_rating  \
# 12   KOSMOS,999 Games,Albi,Astrel Games,Bergsala En...        7.26569
# 44   ABACUSSPIELE,Brain Games,cutia.ro,dV Giochi,G3...        6.48827
# 79   Hans im Glück Verlags-GmbH,999 Games,Användbar...        7.80446
# 151  (Unknown),Alga,Barnes & Noble,Borras Plana S.A...        5.57906
# 226  999 Games,Competo / Marektoy,Devir,Filosofia É...        6.77393
#
#     users_rated cat_kids cat_war
# 12        67655    False   False
# 44         4824    False   False
# 79        18423    False   False
# 151       21836    False    True
# 226       11105    False   False
#
# [5 rows x 24 columns]
