# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
df = pd.read_csv('resources/clean.csv')

# %%
# Display the first few rows
print(df.head())

# Summary of the DataFrame
print(df.info())

# Summary statistics
print(df.describe())
# Out:
#    game_id                                        description  max_players  \
# 0        1  Die Macher is a game about seven sequential po...            5
# 1        2  Dragonmaster is a trick-taking card game based...            4
# 2        3  Part of the Knizia tile-laying trilogy, Samura...            4
# 3        4  When you see the triangular box and the luxuri...            4
# 4        5  In Acquire, each player strategically invests ...            6
#
#    max_playtime  min_age  min_players  min_playtime            name  \
# 0           240       14            3           240      Die Macher
# 1            30       12            3            30    Dragonmaster
# 2            60       10            2            30         Samurai
# 3            60       12            2            60  Tal der Könige
# 4            90       12            3            90         Acquire
#
#    playing_time                        category expansion  \
# ...

# %%
# Histogram for 'average_rating'
plt.figure(figsize=(10, 6))
sns.histplot(df['average_rating'], bins=20, kde=True)
plt.title('Distribution of Average Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Frequency')
plt.show()

# Repeat for other numerical columns as needed

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Now calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# These box plots illustrate the spread and identify outliers in the average_rating, users_rated, and max_playtime features, showing the central tendency and variability of these features.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=numeric_df[['average_rating', 'users_rated', 'max_playtime']], palette='Set2')
plt.title('Box Plots of Board Game Ratings and Playtime', fontsize=16)
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This scatter plot visualizes the relationship between average_rating and users_rated, providing insight into how user ratings might correlate with the number of ratings given.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=numeric_df, x='average_rating', y='users_rated', color='purple', alpha=0.7)
plt.title('Average Rating vs. Users Rated for Board Games', fontsize=16)
plt.xlabel('Average Rating')
plt.ylabel('Number of Users Rated')
plt.axhline(y=numeric_df['users_rated'].mean(), color='red', linestyle='--', label='Average Users Rated')
plt.legend()
plt.show()

# %% [markdown]
# This heatmap displays the correlation matrix for the numeric features, highlighting relationships between different board game characteristics, where colors indicate the strength and direction of correlations.

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = numeric_df[['max_players', 'max_playtime', 'min_age', 'min_players', 'min_playtime', 'playing_time', 'average_rating', 'users_rated']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Board Game Features', fontsize=16)
plt.show()

# %%
# Use a default Matplotlib style
plt.style.use('ggplot')

# List of numerical columns to plot
numeric_columns = ['max_players', 'max_playtime', 'min_age', 'min_players', 
                   'min_playtime', 'playing_time', 'average_rating', 'users_rated']

# Create histograms for each numerical column
plt.figure(figsize=(14, 10))
for i, column in enumerate(numeric_columns):
    plt.subplot(3, 3, i + 1)  # Adjust the layout as needed
    sns.histplot(df[column], bins=30, kde=True, color='skyblue', edgecolor='black')
    plt.title(f'Distribution of {column}', fontsize=14)
    plt.xlabel(column, fontsize=12)
    plt.ylabel('Frequency', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# Breakdown of Exploratory Data Analysis
# Summary Statistics: The initial step involves computing summary statistics for the numerical features within the dataset. This includes key metrics such as the mean, median, standard deviation, and range, which help in understanding the central tendency and spread of the data.
#
# Distribution Analysis: The subsequent phase focuses on analyzing the distribution of each numerical feature to comprehend how values are dispersed. This step is crucial for identifying patterns, such as whether the data adheres to a normal distribution or exhibits skewness in one direction.
#
# Outlier Detection: At this stage, outliers are scrutinized to identify any extreme values that may have a significant impact on the analysis results. Recognizing these outliers is essential for maintaining the integrity of later statistical tests and modeling efforts.
#
# Relationship Exploration: This part of the analysis involves examining the relationships between pairs of numerical variables to uncover any existing correlations. Understanding these relationships is beneficial for determining whether variations in one variable correspond with changes in another, which can aid in feature selection during modeling.
#
# Correlation Assessment: Here, the focus is on evaluating the correlations among numerical features to gauge how closely they are linked. This evaluation is important for recognizing which features might offer redundant information versus those that may provide more valuable insights for modeling.
#
# Categorical Feature Analysis: The examination of categorical features entails analyzing their distributions and frequencies. This analysis helps in identifying prevalent categories and potential imbalances that could impact the overall findings.
#
# Multi-Variable Relationships: Investigating multi-variable relationships assists in recognizing patterns or interactions among several features. This knowledge is crucial for forming a well-rounded perspective on how different aspects of the data relate to each other.
#
# Individual Feature Examination: Each feature within the dataset is reviewed separately to glean insights into its distinct characteristics. This includes evaluating the range, typical values, and any issues that may arise, such as missing or inconsistent data.
#
# Conclusion
# In summary, the exploratory data analysis process constitutes a detailed evaluation of the dataset that reveals significant insights regarding the features' characteristics, relationships, and distributions. This foundational knowledge is vital for guiding the next steps in data preparation and modeling efforts.
